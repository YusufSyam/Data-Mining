# %%
# Import library yang dibutuhkan
import pandas as pd
import os

# %% [markdown]
# ## 1. Mengambil data dari Kaggle

# %% [markdown]
# Untuk menggunakan kaggle, pertama-tama kita harus menginstall librarynya dan menuliskan api key

# %%
# !pip install kaggle
# Out:
# ...
#      |████████████████████████████████| 127 kB 2.7 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.6
#     Uninstalling urllib3-1.26.6:
#       Successfully uninstalled urllib3-1.26.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %% [markdown]
# Mendefinisikan username dan api key, baru mengimport kaggle

# %%
os.environ['KAGGLE_USERNAME'] = "zououoz"
os.environ['KAGGLE_KEY'] = "3a51d9a27b0809a05d07960ae0f80285"

import kaggle

# %% [markdown]
# Mendownload data dari kaggle

# %%
# !kaggle datasets download -d ankitkalauni/amazon-top-rated-smartphones-accessories-2021 --force
# Out:
# ...
#   0% 0.00/39.4k [00:00<?, ?B/s]
# 100% 39.4k/39.4k [00:00<00:00, 15.6MB/s]

# %% [markdown]
# Unzip data, karena data yang didownload berupa file zip

# %%
# !unzip -q /content/amazon-top-rated-smartphones-accessories-2021.zip
# Out:
# replace Amazon Top Rated Smartphones  Accessories 2021   - amazon_top_rated_smartphones.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y

# %% [markdown]
# Barulah datanya bisa diolah

# %%
data1= pd.read_csv('Amazon Top Rated Smartphones  Accessories 2021   - amazon_top_rated_smartphones.csv')

# Menampilkan 5 data teratas
data1.head()
# Out:
#                                           Smartphone  ... Status of stock & more offers
# 0  Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | 2....  ...                           NaN
# 1  Redmi 9A (Nature Green, 2GB RAM, 32GB Storage)...  ...                           NaN
# 2  Redmi 9A (Sea Blue 2GB RAM 32GB Storage) | 2GH...  ...                           NaN
# 3  Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Stora...  ...                           NaN
# 4  Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage) ...  ...                           NaN
#
# [5 rows x 8 columns]

# %% [markdown]
# ## 2. Mengambil data dari dokumen

# %%
# Mengimport library untuk mengupload file
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-04959620-ba71-4726-8094-714609acfedb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04959620-ba71-4726-8094-714609acfedb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-red.csv to winequality-red (2).csv

# %%
# Membaca data csv lalu menampilkan 5 data teratas
data2= pd.read_csv('winequality-red.csv', sep=';')
data2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %% [markdown]
# ## 3. Mengambil data dari URL

# %%
# Membaca data csv lalu menampilkan 5 data teratas
data3= pd.read_csv('https://drive.google.com/uc?export=download&id=1sVgAGR32bTQaiF9GXvDwQCa5_KtN9pLe', sep="\t", error_bad_lines=False, header=None)
data3.head()
# Out:
# b'Skipping line 9: expected 8 fields, saw 10\nSkipping line 37: expected 8 fields, saw 10\nSkipping line 62: expected 8 fields, saw 9\nSkipping line 70: expected 8 fields, saw 9\nSkipping line 108: expected 8 fields, saw 9\nSkipping line 137: expected 8 fields, saw 9\nSkipping line 171: expected 8 fields, saw 9\nSkipping line 172: expected 8 fields, saw 9\nSkipping line 174: expected 8 fields, saw 9\nSkipping line 203: expected 8 fields, saw 9\nSkipping line 205: expected 8 fields, saw 9\n'
#        0      1       2      3      4      5      6  7
# 0  15.26  14.84  0.8710  5.763  3.312  2.221  5.220  1
# 1  14.88  14.57  0.8811  5.554  3.333  1.018  4.956  1
# 2  14.29  14.09  0.9050  5.291  3.337  2.699  4.825  1
# 3  13.84  13.94  0.8955  5.324  3.379  2.259  4.805  1
# 4  16.14  14.99  0.9034  5.658  3.562  1.355  5.175  1

# %% [markdown]
# ## 4. Mengambil data JSON

# %% [markdown]
# Ada setidaknya dua cara untuk mengimport data berbentuk JSON

# %% [markdown]
# **A. Dengan library JSON**

# %%
# Mengimport library JSON
import json
  
# Membaca file JSON
f= open('unece.json',)
data4_1 = json.load(f)

# Menampilkan data pertama
data4_1[0]
# Out:
# {'Adolescent fertility rate': 15.24086,
#  'Area (square kilometres)': 28748,
#  'Computer use, 16-24, female': None,
#  'Computer use, 16-24, male': None,
#  'Computer use, 25-54, female': None,
#  'Computer use, 25-54, male': None,
#  'Computer use, 55-74, female': None,
#  'Computer use, 55-74, male': None,
#  'Consumer price index, growth rate': 0.04958,
#  'Country': 'Albania',
#  'Economic acivity rate, women 15-64': None,
#  'Economic activity rate, men 15-64': None,
#  'Employment in agriculture, hunting, forestry and fishing (ISIC Rev. 4 A), share of total employment': None,
#  'Employment in construction (ISIC Rev. 4 F), share of total employment': None,
#  'Employment in finance, real estate and business services (ISIC Rev. 4 K-N), share of total employment': None,
#  'Employment in industry and energy (ISIC Rev. 4 B-E), share of total employment': None,
#  'Employment in other service activities (ISIC Rev. 4 R-U), share of total employment': None,
# ...

# %% [markdown]
# **B. Dengan read_json dari pandas**

# %%
# Membaca data JSON lalu menampilkan 5 data pertama
data4_2= pd.read_json('unece.json')
data4_2.head()
# Out:
#    Country  ...  Total length of railway lines (km)
# 0  Albania  ...                               400.0
# 1  Albania  ...                               409.0
# 2  Albania  ...                               428.0
# 3  Albania  ...                               428.0
# 4  Albania  ...                               428.0
#
# [5 rows x 79 columns]

# %% [markdown]
# ## 5. Mengambil data dengan package yang belum tersedia

# %% [markdown]
# **A. Data berformat SPSS (.sav)**

# %% [markdown]
# **1. Dengan menggunakan library pyreadstat**

# %% [markdown]
# Pertama-tama kita install library nya

# %%
# !pip install pyreadstat

# %%
# Mengimport pyreadstat
import pyreadstat

# Membaca dataset yang berbentuk .sav
data5_1, meta = pyreadstat.read_sav("survey.sav")
# Menampilkan 5 data pertama
data5_1.head()
# Out:
#       id  sex   age  marital  ...  LG10negaff     MAH_1     COO_1      MAH_2
# 0  415.0  2.0  24.0      4.0  ...    1.623249  0.958016  0.000045  18.100643
# 1    9.0  1.0  39.0      3.0  ...    1.544068  3.640753  0.015852  14.482011
# 2  425.0  2.0  48.0      4.0  ...    1.146128  1.307418  0.014042  14.214291
# 3  307.0  1.0  41.0      5.0  ...    1.556303  1.314176  0.005404  14.169411
# 4  440.0  1.0  23.0      1.0  ...    1.041393  2.718887  0.000376  13.702974
#
# [5 rows x 134 columns]

# %% [markdown]
# **2. Dengan menggunakan read_spss dari pandas**

# %%
# Membaca dataset berbentuk sav, tapi dengan library pandas
data5_2= pd.read_spss("survey.sav")
data5_2.head()
# Out:
#       id      sex   age  ...     MAH_1     COO_1      MAH_2
# 0  415.0  FEMALES  24.0  ...  0.958016  0.000045  18.100643
# 1    9.0    MALES  39.0  ...  3.640753  0.015852  14.482011
# 2  425.0  FEMALES  48.0  ...  1.307418  0.014042  14.214291
# 3  307.0    MALES  41.0  ...  1.314176  0.005404  14.169411
# 4  440.0    MALES  23.0  ...  2.718887  0.000376  13.702974
#
# [5 rows x 134 columns]

# %% [markdown]
# ### **B. Data berbentuk citra**

# %%
# Mengimport library PIL untuk gambar
import PIL
import matplotlib.pyplot as plt
import numpy as np


# Mendefinisikanpath
path = os.listdir("../content/drive/MyDrive/twice/")

# Membuat fungsi untuk membuka gambar
load_img = lambda filename: np.array(PIL.Image.open(f"../content/drive/MyDrive/twice/{filename}"))

# Membuat variabel untuk jumlah subplot horizontal
w = 3
# Variabel untuk jumlah subplot vertical
h = 3

# Mendefinisikan panjang lebar plot sesuai variabel di atas
_, axes_list = plt.subplots(h, w, figsize=(6*w, 4*h))

# Perulangan untuk menampilkan gambar
for axes in axes_list:
    for ax in axes:
        ax.axis('off')

        # Memilih gambar secara acak
        img = np.random.choice(path)


        # Menampilkan gambar
        ax.imshow(load_img(img))
        ax.set_title(img)
